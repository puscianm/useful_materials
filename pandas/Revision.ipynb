# %% [markdown]
# Useful youtube video: https://www.youtube.com/watch?v=_gaAoJBMJ_Q

# %%
import pandas as pd

# %%
learning_dataset = pd.read_csv("learning_dataset.csv")

# %%
learning_dataset
# Out:
#             productname        date farmprice atlantaretail chicagoretail  \
# 0          Strawberries  2019-05-19     $1.16         $2.23         $1.70
# 1       Romaine Lettuce  2019-05-19     $0.35         $1.72         $2.00
# 2      Red Leaf Lettuce  2019-05-19     $0.32         $1.84         $1.84
# 3              Potatoes  2019-05-19     $1.50         $5.32         $5.14
# 4               Oranges  2019-05-19     $0.41         $1.42         $1.45
# ...                 ...         ...       ...           ...           ...
# 15761   Broccoli Crowns  1999-10-24     $0.29         $1.46         $0.00
# 15762  Broccoli Bunches  1999-10-24     $0.23         $1.21         $0.00
# 15763       Cauliflower  1999-10-24     $0.19         $1.01         $0.00
# 15764           Carrots  1999-10-24     $0.12         $0.64         $0.00
# 15765        Cantaloupe  1999-10-24     $0.21         $0.54         $0.00
#
#       losangelesretail newyorkretail averagespread
# ...

# %%
learning_dataset.dtypes
# Out:
# productname         object
# date                object
# farmprice           object
# atlantaretail       object
# chicagoretail       object
# losangelesretail    object
# newyorkretail       object
# averagespread       object
# dtype: object

# %% [markdown]
# ***

# %% [markdown]
# ## Create pipelines for common transforms

# %%
def numeric_to_numbers(input_df, string_to_delete):
    df = input_df.copy()
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(learning_dataset[col].str.replace(string_to_delete,''),errors='raise')
            print("CONVERTED column " + col)
        except:
            #print("NIE ZAMIENIONO kolumny " + col)
            pass
    return df

# %%
processed_dataset = numeric_to_numbers(learning_dataset, '$')
processed_dataset
# Out:
# CONVERTED column farmprice
# CONVERTED column atlantaretail
# CONVERTED column chicagoretail
# CONVERTED column losangelesretail
# CONVERTED column newyorkretail
#             productname        date  farmprice  atlantaretail  chicagoretail  \
# 0          Strawberries  2019-05-19       1.16           2.23           1.70
# 1       Romaine Lettuce  2019-05-19       0.35           1.72           2.00
# 2      Red Leaf Lettuce  2019-05-19       0.32           1.84           1.84
# 3              Potatoes  2019-05-19       1.50           5.32           5.14
# 4               Oranges  2019-05-19       0.41           1.42           1.45
# ...                 ...         ...        ...            ...            ...
# 15761   Broccoli Crowns  1999-10-24       0.29           1.46           0.00
# 15762  Broccoli Bunches  1999-10-24       0.23           1.21           0.00
# 15763       Cauliflower  1999-10-24       0.19           1.01           0.00
# ...

# %%
processed_dataset.dtypes
# Out:
# productname          object
# date                 object
# farmprice           float64
# atlantaretail       float64
# chicagoretail       float64
# losangelesretail    float64
# newyorkretail       float64
# averagespread        object
# dtype: object

# %% [markdown]
# # Saving processed data with type-supportive method

# %%
processed_dataset.to_parquet
